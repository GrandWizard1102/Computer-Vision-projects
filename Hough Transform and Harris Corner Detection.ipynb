# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
image=cv2.imread(r"C:\Users\student\Pictures\Screenshots\Screenshot 2025-04-24 111901.png")
image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
plt.imshow(gray,cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 597.5, 139.5, -0.5)

# %%
edges=cv2.Canny(gray,50,100,apertureSize=3)
plt.imshow(edges,cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 597.5, 139.5, -0.5)

# %%
lines=cv2.HoughLinesP(edges,1,np.pi/180,100,50,10)
lines.shape
# Out:
# (7, 1, 4)

# %%
if lines is not None:
    for line in lines:
        x1,y1,x2,y2=line[0]

cv2.line(image,(x1,y1),(x2,y2),(0,0,255),4)
plt.imshow(image,cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 597.5, 139.5, -0.5)

# %%
dst=cv2.cornerHarris(gray,2,3,0.04)
dst=cv2.dilate(dst,None)
image[dst>0.01*dst.max()]=(255,0,0)
plt.imshow(image,cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 597.5, 139.5, -0.5)
